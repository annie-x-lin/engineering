# %%
from matplotlib.image import imread
import matplotlib.pyplot as plt
import numpy as np
from numpy import diag
from numpy import dot
from numpy import zeros
from scipy.linalg import svd
import os

Image = imread('flower.jpg')
BandW = np.mean(Image, -1);

img = plt.imshow(BandW)
img.set_cmap('gray')
plt.axis('off')
plt.title('Original')
plt.show

BandW



U, s, VT = svd(BandW)

def function1(sigma,n):
    for x in range (n,200,+1):
        sigma[x]=0
n = 10
function1(s,n)

Sigma = zeros((BandW.shape[0], BandW.shape[1]))
Sigma[:BandW.shape[1], :BandW.shape[1]] = diag(s)
BandW_compressed = U.dot(Sigma.dot(VT))

img = plt.imshow(BandW_compressed)
img.set_cmap('gray')
plt.axis('off')
plt.title('r = ' + str(n))
plt.show()

BandW_compressed
# Out:
# array([[ 74.93624782,  67.06814607,  56.58532088, ..., 101.71960551,
#          93.23138031,  96.53291529],
#        [ 66.82886579,  59.51250602,  49.75593586, ...,  85.9145221 ,
#          78.65034175,  82.46780339],
#        [ 74.23942512,  66.46071849,  56.40765765, ...,  82.56019989,
#          76.23222287,  77.96000465],
#        ...,
#        [  2.13084659,   1.39299679,   0.49348392, ...,  -7.6976329 ,
#         -19.68462184, -31.53975535],
#        [ -3.78354954,  -5.75756058,  -7.73900815, ..., -13.1321575 ,
#         -28.81284857, -41.37351036],
#        [ -0.73101664,  -2.53524322,  -4.81886177, ..., -28.72211714,
#         -42.73299392, -56.77974918]])

# %%
U, s, VT = svd(BandW)

def function1(sigma,n):
    for x in range (n,200,+1):
        sigma[x]=0
n = 25
function1(s,n)

Sigma = zeros((BandW.shape[0], BandW.shape[1]))
Sigma[:BandW.shape[1], :BandW.shape[1]] = diag(s)
BandW_compressed = U.dot(Sigma.dot(VT))

img = plt.imshow(BandW_compressed)
img.set_cmap('gray')
plt.axis('off')
plt.title('r = ' + str(n))
plt.show()

BandW_compressed
# Out:
# array([[ 12.34734879,  11.81702116,  14.07186181, ...,  -2.6450925 ,
#          -6.0957435 ,  -7.35316578],
#        [ -3.24867811,  -5.37124777,  -7.33532506, ..., -14.68828265,
#         -14.57126411,  -9.85847006],
#        [ 12.52858127,   8.26256101,   1.85889119, ...,  -2.36020299,
#           4.07192788,   9.45067476],
#        ...,
#        [ 13.81662995,  15.3187025 ,  15.07908174, ..., -15.52180833,
#         -16.64346207, -19.63104921],
#        [  5.53910584,   5.48600079,   5.59523869, ..., -26.2684383 ,
#         -27.86125041, -26.36379822],
#        [ 10.3976329 ,  10.94537531,  13.09187376, ..., -30.50836575,
#         -30.82336888, -32.59966819]])

# %%
U, s, VT = svd(BandW)

def function1(sigma,n):
    for x in range (n,200,+1):
        sigma[x]=0
n = 50
function1(s,n)

Sigma = zeros((BandW.shape[0], BandW.shape[1]))
Sigma[:BandW.shape[1], :BandW.shape[1]] = diag(s)
BandW_compressed = U.dot(Sigma.dot(VT))

img = plt.imshow(BandW_compressed)
img.set_cmap('gray')
plt.axis('off')
plt.title('r = ' + str(n))
plt.show()

BandW_compressed
# Out:
# array([[-7.72886947e-02,  3.04167587e+00,  1.50624574e+01, ...,
#         -4.58959268e+00, -3.97524618e-01,  6.04921254e+00],
#        [-1.05067149e+00, -2.62292461e+00,  9.66089530e-03, ...,
#         -3.38812992e+00, -3.81460406e+00, -3.33988556e+00],
#        [ 1.65484534e+00, -1.81141926e+00, -1.09645280e+01, ...,
#          4.43463916e+00,  1.82011040e+01,  2.03790133e+01],
#        ...,
#        [-5.55321141e+00, -1.13587017e+00,  2.61191933e+00, ...,
#          2.58272292e-01,  3.62862565e+00,  4.05217714e+00],
#        [-1.89644564e+01, -1.95148446e+01, -1.81346906e+01, ...,
#          4.47941620e+00,  3.62570331e+00,  4.01512612e+00],
#        [ 5.58296092e+00, -3.83058331e-01, -8.20368400e+00, ...,
#          6.89449206e-02, -4.94724686e+00, -8.61627139e+00]])

# %%
U, s, VT = svd(BandW)

def function1(sigma,n):
    for x in range (n,200,+1):
        sigma[x]=0
n = 100
function1(s,n)

Sigma = zeros((BandW.shape[0], BandW.shape[1]))
Sigma[:BandW.shape[1], :BandW.shape[1]] = diag(s)
BandW_compressed = U.dot(Sigma.dot(VT))

img = plt.imshow(BandW_compressed)
img.set_cmap('gray')
plt.axis('off')
plt.title('r = ' + str(n))
plt.show()

BandW_compressed
# Out:
# array([[  0.69222644,   5.55855638,   5.87770473, ...,  -0.71936755,
#           3.98701726,   1.12037743],
#        [ -0.45834297,  -3.95863988,  -4.01903104, ...,  -3.90630884,
#          -1.82271508,  -0.22435926],
#        [ -3.25631674,  -6.51357878,  -4.89954386, ...,   2.27667968,
#           3.25111907,   2.85599573],
#        ...,
#        [ -1.43714133,   6.61649932,   3.76943843, ...,   2.91711095,
#           2.22492198,   5.9968805 ],
#        [  0.79524627,   3.13075726,   1.17270757, ...,   1.08257005,
#           3.99884849,   5.47986794],
#        [ -2.19713386, -12.57804818,   2.33133079, ...,   7.5699996 ,
#           4.89807156,  -1.24440563]])
